# %% [markdown]
# ## Modeling with Julia with Ipopt
#
# Anything with an _a_ reference relates to 'our' team.
# Anything with a _b_ reference relates to 'their' team.

# %%
using PyCall
println(PyCall.python)
# Out:
# /Users/lauraroettges/.julia/conda/3/x86_64/bin/python

# %%
using PyCall
pyimport_conda("pandas", "pandas")
# Out:
# PyObject <module 'pandas' from '/Users/lauraroettges/.julia/conda/3/x86_64/lib/python3.10/site-packages/pandas/__init__.py'>

# %%
using PyCall
pd = pyimport("pandas")
# Out:
# PyObject <module 'pandas' from '/Users/lauraroettges/.julia/conda/3/x86_64/lib/python3.10/site-packages/pandas/__init__.py'>

# %%
using DataFrames, PyCall

#Define Data
p_a1 = 0.000518  # (precomputed) probability of score when 5v5
p_b1 = 0.000518  # (precomputed) probability of score when 5v5

p_a2 = 0.00310   # (precomputed) probability that we score during a given second in 6v5 play
p_b2 = 0.00851   # (precomputed) probability that the opponent scores during a given second in 6v5 play

T_big = 1200 # number of seconds remaining in the game at start of period 3 (20 minutes)

comb_df = pd.read_pickle("../precompute_combinations/precomputed_combinations_df.pkl")
println(comb_df.head())

function choose(n, k)
    #found out through trial and error n must be less than 1200 can not = 1200
    index = n * 1201 + k
    #because of julia need to add 1 to index
    index += 1
    return comb_df.loc[index]["n_choose_k"]
end


#A_0 = [] #TODO: stochastic set -  Our team’s current score (before decision)
#B_0 = [] #TODO: stochastic set -  Their team’s current score (before decision)

scenarios = [:tied, :behind_one, :behind_two]
strategies = [:pull_goalie, :play_normal]

a_0 = Dict(zip(scenarios, [0, 0, 0]))
b_0 = Dict(zip(scenarios, [0, 1, 2]))

#going to start by assuming we are in the behind 1 scenario
A_0 = a_0[:behind_one]
B_0 = b_0[:behind_one]

M = 3599 #be the maximum possible value of d (if their team scored every second of the game and our team never scored)
# Out:
# PyObject            n  k n_choose_k
# new_index
# 0          0  0          1
# 1201       1  0          1
# 1202       1  1          1
# 2402       2  0          1
# 2403       2  1          2
# 3599

# %% [markdown]
# $\mathbb{P}[\mathscr{E}_i] = \mathbb{P}[(G_{a1} == g_{a1}) \& (G_{a2} == g_{a2}) \& (G_{b1} == g_{b1}) \& (G_{b2} = g_{b2})]$ \\
#     $ = {s \choose g_{a1}}(p_{a1})^{g_{a1}}(1 - p_{a1})^{s - g_{a1}} \cdot {s \choose g_{b1}}(p_{b1})^{g_{b1}}(1 - p_{b1})^{s - g_{b1}} \cdot {T - s \choose g_{a2}}(p_{a2})^{g_{a2}}(1 - p_{a2})^{T - s - g_{a2}} \cdot {T - s \choose g_{b2}}(p_{b2})^{g_{b2}}(1 - p_{b2})^{T - s - g_{b2}}$
#
# Need to break this down:
# ${s \choose g_{a1}}(p_{a1})^{g_{a1}}(1 - p_{a1})^{s - g_{a1}} \cdot {s \choose g_{b1}}(p_{b1})^{g_{b1}}(1 - p_{b1})^{s - g_{b1}} \cdot {T - s \choose g_{a2}}(p_{a2})^{g_{a2}}(1 - p_{a2})^{T - s - g_{a2}} \cdot {T - s \choose g_{b2}}(p_{b2})^{g_{b2}}(1 - p_{b2})^{T - s - g_{b2}}$

# %%
function probability_of_event(s, T, prob_a1, prob_b1, prob_a2, prob_b2, ga_before, gb_before, ga2, gb2)
    
    #s = number of seconds in epoch 1 (5v5)
    #T = number of seconds in epoch 2 (6v5)
    #prob_a1 = probability of scoring in epoch 1 (5v5)
    #prob_b1 = probability of opponent scoring in epoch 1 (5v5)
    #prob_a2 = probability of scoring in epoch 2 (6v5)
    #prob_b2 = probability of opponent scoring in epoch 2 (6v5)
    #ga_before = number of goals our team has before goalie pull (epoch 0 & 1)
    #gb_before = number of goals their team has before after goalie pull (epoch 0 & 1)
    #ga2 = number of goals our team has after goalie pull (epoch 2)
    #gb2= number of goals their team has after goalie pull (epoch 2)
    #ensure relevant values are integers
    s = Int(s)
    T = Int(T)
    ga_before = Int(ga_before)
    gb_before = Int(gb_before)
    ga2 = Int(ga2)
    gb2 = Int(gb2)

    #because indicies 
    calcd_prob = choose(s, ga_before) * prob_a1^ga_before * (1 - prob_a1)^(s - ga_before) * choose(s, gb_before) * prob_b1^gb_before * (1 - prob_b1)^(s - gb_before) * choose(T-s, ga2) * prob_a2^ga2 * (1 - prob_a2)^(T - s - ga2) * choose(T-s, gb2) * prob_b2^gb2 * (1 - prob_b2)^(T - s - gb2)
    return calcd_prob
end
# Out:
# probability_of_event (generic function with 1 method)

# %%
# Generate all possible states
# Some extra notes:
#important they must all be ints and they must all be >= 0
# 0 =< ga1 <= s #assuming we can't score more than the number of seconds in epoch 1 (5v5) 
# 0 =< gb1 <= s #assuming we can't score more than the number of seconds in epoch 1 (5v5) 

# 0 =< ga2 <= T-s #assuming we can't score more than the number of seconds in epoch 2 (6v5)
# 0 =< gb2 <= T-s #assuming we can't score more than the number of seconds in epoch 2 (6v5) 

#if we want to make s interval a minute for computational tractability could do T = 5 * 60 = 300 (5 minutes)

#will start with just 2 minutes
T_big = 5 * 60  #2 minutes

T_big = T_big / 10 #I want S to be 10 second increments
# then also need to update probabilities by a factor of 10 
p_a1 = p_a1*10
p_b1 = p_b1*10

p_a2 = p_a2*10
p_b2 = p_b2*10
states = []
for s in 1:T_big
    for ga1 in 0:s
        for gb1 in 0:s
            for ga2 in 0:T-s
                for gb2 in 0:T-s
                    push!(states, (s, ga1, gb1, ga2, gb2))
                end
            end
        end
    end
end

# %%
# Generate probabilities
probabilities = Dict()
#effectively could precompute w 
for state in states
    s, ga1, gb1, ga2, gb2 = state
    #println("state: ", state)
    prob = probability_of_event(s, T, p_a1, p_b1, p_a2, p_b2, ga1, gb1, ga2, gb2)
    #println("prob: ", prob)
    probabilities[state] = prob
end
;

# %%
# I want to save this dictionary to a file so I can load it later
using Serialization

# Save the dictionary to a file
open("probabilities_dict.jls", "w") do io
    serialize(io, probabilities)
end
open("success_state_dict.jls", "w") do io
    serialize(io, win_probs)
end

#may also want to save as a JSON file as back up 
using JSON

# Save the dictionary to a file
open("probabilities_dict_backup.json", "w") do io
    JSON.print(io, probabilities)
end
open("success_state_dict_backup.json", "w") do io
    JSON.print(io, win_probs)
end

# %%
using Serialization
# Load the dictionary from the file
probabilities_loaded = open("probabilities_dict.jls", "r") do io
    deserialize(io)
end

# %%
#OLD DO NOT USE
using JuMP, HiGHS, MathOptInterface

# I think M can now be 359 (since we are now in 10 second increments)
# M = 359 # I will start with this commented though just in case

model = Model()

# Variables
# assuming we don't choose s = 0 (i.e. pull the goalie immediately - TODO: check w/ Ryan) 
@variable(model, 1 <= s <= T_big, Int)      # s: how many seconds to wait before pulling the goalie 
@variable(model, y, Bin)          # y: indicator variable for final score difference
                                  # y = 1 => d is positive (indicating a win or tie), y = 0 => or negative (indicating a loss)
# @variable(model, d, Int)          # d: final score difference (our team - their team)

# Initialize an empty dictionary to store the variables
w = Dict{Tuple{Int, Int, Int, Int, Int}, JuMP.VariableRef}()

for s in 1:T_big
    for ga1 in 0:s
        for gb1 in 0:s
            for ga2 in 0:T_big-s
                for gb2 in 0:T_big-s
                    # Set up variable w for each scenario

                    w[(s, ga1, gb1, ga2, gb2)] = @variable(model, base_name="w_$(s)_$(ga1)_$(gb1)_$(ga2)_$(gb2)")
                    # Set up w[i] < probabilities of state 
                    # (s, T, p_a1, p_b1, p_a2, p_b2, ga1, gb1, ga2, gb2)
                    curr_prob = probability_of_event(s, T_big, p_a1, p_b1, p_a2, p_b2, ga1, gb1, ga2, gb2)
                    #@expression(model, curr_prob, probability_of_event(s, T, p_a1, p_b1, p_a2, p_b2, ga1, gb1, ga2, gb2))
                    # Convert curr_prob to a Julia type if it is a PyCall.jlwrap object
                    curr_prob = convert(Float64, curr_prob)
                    @constraint(model, w[(s, ga1, gb1, ga2, gb2)] <= curr_prob)
                    d = (A_0 + ga1 + ga2) + 1 - (B_0 + gb1 + gb2)  # Calculate the score difference
                    @constraint(model, w[(s, ga1, gb1, ga2, gb2)] >= 0)
                    @constraint(model, w[(s, ga1, gb1, ga2, gb2)] >= d)
                    @constraint(model, w[(s, ga1, gb1, ga2, gb2)] <= M - (M * y))
                    @constraint(model, w[(s, ga1, gb1, ga2, gb2)] <= d + M * y)
                    #@constraint(model, w[(s, ga1, gb1, ga2, gb2)] <= M * y)
                    #@constraint(model, w[(s, ga1, gb1, ga2, gb2)] <= d + M * (1-y))
                end
            end
        end
    end
end

# Objective
@objective(model, Max, sum(w[key] for key in keys(w)))
;

# %%
#OLD DO NOT USE

using JuMP, HiGHS, MathOptInterface

model = Model()
# I think M can now be 359 (since we are now in 10 second increments)
M = 359 # I will start with this commented though just in case

#Variables
#assuming we don't choose s = 0 (i.e. pull the goalie immediately - TODO: check w/ Ryan) 
@variable(model, 0 <= s <= T, Int)      # s: how many seconds to wait before pulling the goalie 
@variable(model, w[1:length(states)] >= 0) # w: probability of each scenario   
@variable(model, y[1:length(states)], Bin) # y: indicator variable for final score difference
                                # y = 0 => d is positive (indicating a win or tie), y = 1 => or negative (indicating a loss) 

#Constraints
# Define constraints based on states (s, ga1, gb1, ga2, gb2)
for (i, state) in enumerate(states)
    s_for_now, ga1, gb1, ga2, gb2 = state
    d = (A_0 +ga1 + ga2) +1 - (B_0 + gb1 + gb2)  # Calculate the score difference
    #println("d: ", d)
    #if d >= 0
    #    y = 0
    #else
    #    y = 1
    #end

    #need to make sure y is appropriately defined
    @constraint(model, M*y[i] <= M - d)


    #@constraint(model, w[i] <= convert(Float64, probabilities[state]))
    #if I don't relate it to probabiliies and only d 
    @constraint(model, w[i] <= convert(Float64, probabilities[state]))) 

    #ok thoughts cant say w is greater than or equal to 0 and less than or equal to d because d could be negative
    #that will make this infeasible

    @constraint(model, w[i] <=  M - (M * y[i]))
    @constraint(model, w[i] <= d + M * y[i])
    
    #need to actually incorporate s appropriately - which I am not doing now, it's a variable I am never using.. 

end

# Objective
@objective(model, Max, sum(w[i] for i in 1:length(states)))
# Out:
# w[1] + w[2] + w[3] + w[4] + w[5] + w[6] + w[7] + w[8] + w[9] + w[10] + w[11] + w[12] + w[13] + w[14] + w[15] + w[16] + w[17] + w[18] + w[19] + w[20] + w[21] + w[22] + w[23] + w[24] + w[25] + w[26] + w[27] + w[28] + w[29] + w[30] + [[...1117459 terms omitted...]] + w[1117490] + w[1117491] + w[1117492] + w[1117493] + w[1117494] + w[1117495] + w[1117496] + w[1117497] + w[1117498] + w[1117499] + w[1117500] + w[1117501] + w[1117502] + w[1117503] + w[1117504] + w[1117505] + w[1117506] + w[1117507] + w[1117508] + w[1117509] + w[1117510] + w[1117511] + w[1117512] + w[1117513] + w[1117514] + w[1117515] + w[1117516] + w[1117517] + w[1117518] + w[1117519]

# %%
using JuMP, HiGHS, MathOptInterface

model = Model()
# I think M can now be 359 (since we are now in 10 second increments)
M = 359 # I will start with this commented though just in case

#Variables
#assuming we don't choose s = 0 (i.e. pull the goalie immediately - TODO: check w/ Ryan) 
@variable(model, 0 <= s <= T, Int)      # s: how many seconds to wait before pulling the goalie 
@variable(model, w[1:length(states)] >= 0) # w: probability of each scenario   
@variable(model, y[1:length(states)], Bin) # y: indicator variable for final score difference
                                # y = 1 => d is positive (indicating a win or tie), y = 0 => or negative (indicating a loss) 

#Constraints
# Define constraints based on states (s, ga1, gb1, ga2, gb2)
for (i, state) in enumerate(states)
    s_for_now, ga1, gb1, ga2, gb2 = state
    d = (A_0 +ga1 + ga2) +1 - (B_0 + gb1 + gb2)  # Calculate the score difference

    #need to make sure y is appropriately defined
    @constraint(model, M*y[i] <= d + M -1)

    #make sure w is either 0 or the probability of the state
    @constraint(model, w[i] <= convert(Float64, probabilities[state]))) 
    @constraint(model, w[i] <= 1-y[i])

    #want to know what s is for each state
    @constraint(model, s == s_for_now)
    
end

# Objective
@objective(model, Max, sum(w[i] for i in 1:length(states)))

# %%
using JuMP, HiGHS, MathOptInterface


#set solver
set_optimizer(model, HiGHS.Optimizer)


# Print constraints
#println("Constraints:")
#for c in all_constraints(model, include_variable_in_set_constraints=true)
#    # Get lower and upper bounds for the constraint
#    try
#        lb = MathOptInterface.get(model, MathOptInterface.LowerBound, c)
#        ub = MathOptInterface.get(model, MathOptInterface.UpperBound, c)
#        if ub < lb
#            println("Conflict detected")
#            println(c)
#        end
#    catch e
#        # Handle cases where bounds are not available
#        println("No bounds available for constraint: ", c)
#    end
#end


println("Number of constraints: ", num_constraints(model, count_variable_in_set_constraints=true))
#print the lengthe of w
println("Length of w: ", length(w))

# Solve the model
@time(optimize!(model))

# Print the results
println("Objective value: ", objective_value(model))
println("pull out the goalie at time s: ", value(s))
# Out:
# Number of constraints: 6705117
# Length of w: 1117519
# Running HiGHS 1.7.2 (git hash: 5ce7a2753): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [1e+00, 4e+02]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 3e+01]
#   RHS    [1e+00, 4e+02]
# Presolving model
# 1161264 rows, 624377 cols, 1248754 nonzeros  2s
# 87490 rows, 78740 cols, 157480 nonzeros  3s
# 69990 rows, 62990 cols, 125980 nonzeros  3s
# 55990 rows, 50390 cols, 100780 nonzeros  3s
# 44790 rows, 40310 cols, 80620 nonzeros  3s
# 35830 rows, 32246 cols, 64492 nonzeros  3s
# 28662 rows, 25795 cols, 51590 nonzeros  4s
# 22928 rows, 20635 cols, 41270 nonzeros  4s
# 18342 rows, 16507 cols, 33014 nonzeros  4s
# 14672 rows, 13204 cols, 26408 nonzeros  4s
# 11736 rows, 10562 cols, 21124 nonzeros  4s
# 9388 rows, 8387 cols, 16774 nonzeros  4s
# 7386 rows, 6385 cols, 12770 nonzeros  4s
# 5384 rows, 4383 cols, 8766 nonzeros  4s
# 3382 rows, 2381 cols, 4762 nonzeros  4s
# 1380 rows, 690 cols, 1380 nonzeros  4s
# 0 rows, 0 cols, 0 nonzeros  4s
# Presolve: Optimal
#
# Solving report
#   Status            Optimal
#   Primal bound      4458016
#   Dual bound        4458016
#   Gap               0% (tolerance: 0.01%)
#   Solution status   feasible
#                     4458016 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            4.34 (total)
#                     4.11 (presolve)
#                     0.00 (postsolve)
#   Nodes             0
#   LP iterations     0 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# 204.180338 seconds (55.88 M allocations: 4.897 GiB, 89.41% gc time)
# Objective value: 4.458016e6
# pull out the goalie at time s: 0.0

# %%
#so far just getting pull them at the very beginning which I know is wrong for 5 minutes 
#I think I need to factor in probability still not just max(d, 0)
#also s is not actually making an appearance in my model

# %%
##Code for debugging
## Print the DataFrame's index and columns for debugging
#println("DataFrame Index: ", comb_df.index)
#println("DataFrame Columns: ", comb_df.columns)
#println("Number of Rows: ", comb_df.shape[1])
#
## Access a specific row
#row = comb_df.loc[1202]
#println("this row put in 1202:", row)
#row = comb_df.loc[1203]
#println("next row put in 1203: ", row)
#row = comb_df.loc[2403]
#println("3rd row put in 2403: ",row)
#
## Access a specific element (ensure the index exists and the column name is correct)
#println("this other thing: ",comb_df.loc[1202]["n_choose_k"])
#
#test_mult = comb_df.loc[1202]["n_choose_k"] * .05
#println("test_mult: ", test_mult)

# %%
using Random
seed = 425 # seed for data generation

N = 1:60 # jobs
M = 1:30 # machines

Random.seed!(seed)

# set time lengths of jobs on each machine
a = zeros(length(M),length(N))
for i in M
    for j in N
        a[i,j] = round(6+Random.rand()*Random.rand(6:25),digits=2)
    end
end

# capacity of each machine
b = Dict(zip(M,[12*sum(a[i,j] for j in N)/length(M) for i in M]))

# cost of running jobs on each machine
c = zeros(length(M),length(N))
for i in M
    for j in N
        c[i,j] = 20+round(Random.rand()*Random.rand(20:60),digits=2)
    end
end

# fixed cost of each machine
h = [30*length(M) for i in M]

# duration of each job (for question (c))
d = [Random.rand(1:10)*Random.rand()+10 for j in N];

# %%
# Create a list of tuples (index, value) from the dictionary b
b_list = collect(b)

# Sort the list by the values in descending order
sorted_b_list = sort(b_list, by = x -> x[2], rev = true)

# Extract the sorted indices
sorted_indices = [x[1] for x in sorted_b_list]

# Rearrange the arrays according to the sorted indices
d_sorted = d[sorted_indices]

# need to sort c and a which are 2D arrays
c_sorted = c[sorted_indices, :]
a_sorted = a[sorted_indices, :]

# Create a dictionary to map original indices to sorted indices
index_map = Dict(original => sorted for (sorted, original) in enumerate(sorted_indices))

# Print the sorted arrays and the index map
println("initial b: ", b)
println("shape of b: ", size(b))
println("sorted b: ", sorted_b_list)
println
println("Sorted indices: ", sorted_indices)
println("Index map: ", index_map)
println("OG a: ", a)
println("Sorted a: ", a_sorted)
println("OG c: ", c)
println("Sorted c: ", c_sorted)
println("OG d: ", d)
println("sorted d: ", d_sorted)
# Out:
# initial b: Dict(5 => 344.75999999999993, 16 => 310.3280000000001, 20 => 320.0879999999999, 12 => 362.072, 24 => 298.73199999999986, 28 => 309.6279999999999, 8 => 290.2560000000001, 17 => 323.34800000000007, 30 => 328.19200000000006, 1 => 337.5000000000001, 19 => 328.864, 22 => 325.2160000000001, 23 => 334.88400000000007, 6 => 325.91199999999986, 11 => 344.82800000000003, 9 => 334.69999999999993, 14 => 340.11599999999993, 3 => 334.04799999999994, 29 => 328.73199999999997, 7 => 331.46, 25 => 326.628, 4 => 342.736, 13 => 318.324, 15 => 329.6239999999999, 2 => 331.43199999999996, 10 => 339.772, 18 => 330.8959999999999, 21 => 326.70399999999995, 26 => 332.6640000000001, 27 => 334.7039999999999)
# sorted b: [12 => 362.072, 11 => 344.82800000000003, 5 => 344.75999999999993, 4 => 342.736, 14 => 340.11599999999993, 10 => 339.772, 1 => 337.5000000000001, 23 => 334.88400000000007, 27 => 334.7039999999999, 9 => 334.69999999999993, 3 => 334.04799999999994, 26 => 332.6640000000001, 7 => 331.46, 2 => 331.43199999999996, 18 => 330.8959999999999, 15 => 329.6239999999999, 19 => 328.864, 29 => 328.73199999999997, 30 => 328.19200000000006, 21 => 326.70399999999995, 25 => 326.628, 6 => 325.91199999999986, 22 => 325.2160000000001, 17 => 323.34800000000007, 20 => 320.0879999999999, 13 => 318.324, 16 => 310.3280000000001, 28 => 309.6279999999999, 24 => 298.73199999999986, 8 => 290.2560000000001]
# Sorted indices: [12, 11, 5, 4, 14, 10, 1, 23, 27, 9, 3, 26, 7, 2, 18, 15, 19, 29, 30, 21, 25, 6, 22, 17, 20, 13, 16, 28, 24, 8]
.4527976514645, 10.118834610367328, 14.948963968551219, 16.94260481862146, 15.267005597712195, 10.58054690686696, 10.869639665074127, 10.578557532642778, 16.58123058385194, 13.193110894972552, 10.922733225053626, 11.947558879813958, 16.374146329459165, 10.301043392357613, 12.406061591746454, 12.715918323757746, 11.014891392473412, 16.689282684811808, 10.166974828395684, 11.929447435602661, 10.120891944821018, 15.18775886950856, 10.013217968089876, 10.788269446045248, 12.885678601717643, 13.038628506451445, 16.588901856364338, 12.234962478813568, 12.225058463130928, 11.860099749363592, 13.28587854758597, 12.029743944062389, 14.631426963154595, 10.68431045391567, 16.103643196915097, 10.51558699815968, 10.03956361623485]
# sorted d: [14.807698184226158, 17.361154160039014, 16.430290126035736, 13.915210637256406, 10.29986166423561, 11.255884718907417, 15.17224979112274, 11.923425937453105, 16.94260481862146, 10.768031851330331, 10.751443725064979, 14.948963968551219, 11.931424047190333, 10.918161141313757, 12.035696930957066, 14.73358672985905, 11.39102183841208, 10.58054690686696, 10.869639665074127, 13.286898361783942, 10.118834610367328, 17.435127730216152, 13.664014964882217, 11.261281779190472, 13.762571097202043, 13.392818867538532, 10.06984154804631, 15.267005597712195, 10.4527976514645, 15.925081771894817]

# %%
#maybe can construct a better lower bound fir t than 0 - get the largest 15 d_j values and sum them, can't be better than that
#also, can't be worse than sum(d_j) - if all jobs run sequentially on one machine

#reformulating problem c

using JuMP, Cbc, HiGHS
m = Model()

#variables
@variable(m, t >= 0) # makespan
@variable(m, x[M,N], Bin) # x[i,j] = 1 if job j is assigned to machine i
@variable(m, z[M], Bin) # z[i] = 1 if machine i is used

#constraints
@constraint(m, capacity[i in M], sum(a_sorted[i,j]*x[i,j] for j in N) <= sorted_b_list[i]) # capacity constraint
@constraint(m, job_assignment[j in N], sum(x[i,j] for i in M) == 1) # each job is assigned to exactly one machine
@expression(m, time_on_machine[i in M], sum(d_sorted[j]*x[i,j] for j in N)) # time on machine i
for i in M
    @constraint(m, t >= time_on_machine[i]) # makespan constraint
end
@constraint(m, sum(z[i] for i in M) <= 15) # at most 15 machines are used

# machine i is used if any job is assigned to it, using a diffferent formulation in attempt to improve performance
for i in M
    for j in N
        @constraint(m, x[i,j] <= z[i])
    end
end 

#remove symmetry
for i in 1:length(M)-1
    @constraint(m, z[i] >= z[i+1])
    #sum of d on z[i] must be greater than or equal to the sum of d on z[i+1]
    @constraint(m, sum(d_sorted[j]*x[i,j] for j in N) >= sum(d_sorted[j]*x[i+1,j] for j in N))
end

#give a better lower bound for t
@constraint(m, t <= sum(d[j] for j in N)) # t must be less than running all jobs sequentially on one machine
max_d = maximum(d)
d_copy = copy(d)
# Sort the copy in descending order
sorted_d_copy = sort(d_copy, rev=true)
println("sorted_d_copy: ", sorted_d_copy)
# Get the sum of the first 14 elements
sum_d_14 = sum(sorted_d_copy[1:14])
println("sum_d_14: ", sum_d_14)
#min_d = minimum(d)
#println("max_d: ", max_d)
#println("min_d: ", min_d)
#since 60 jobs
@constraint(m, t >= max_d) # t must be greater than the longest job
@constraint(m, t <= sum(d[j] for j in N)-sum_d_14) # t must be less than running all jobs sequentially on one machine

@objective(m, Min, t) # minimize makespan

#solve_and_print(m, x, z, 'C', nothing, t)

#d_sorted = sort(d, rev=false)
#@constraint(m, t >= sum(d_sorted[1:15])) # can't be worse than the sum of the 15 longest jobs (lower bound)
# Out:
# BoundsError: attempt to access 30-element Vector{Float64} at index [31]
#
# Stacktrace:
#   [1] getindex(A::Vector{Float64}, i1::Int64)
#     @ Base ./essentials.jl:13
#   [2] macro expansion
#     @ ~/.julia/packages/MutableArithmetics/OfRUD/src/rewrite_generic.jl:268 [inlined]
#   [3] macro expansion
#     @ ~/.julia/packages/MutableArithmetics/OfRUD/src/rewrite.jl:340 [inlined]
#   [4] macro expansion
#     @ ~/.julia/packages/JuMP/7rBNn/src/macros.jl:257 [inlined]
#   [5] macro expansion
#     @ ~/.julia/packages/JuMP/7rBNn/src/macros/@expression.jl:86 [inlined]
#   [6] (::var"#29#30"{Model})(i::Int64)
#     @ Main ~/.julia/packages/JuMP/7rBNn/src/Containers/macro.jl:545
#   [7] #87
#     @ ~/.julia/packages/JuMP/7rBNn/src/Containers/container.jl:124 [inlined]
#   [8] iterate
#     @ ./generator.jl:47 [inlined]
#   [9] collect(itr::Base.Generator{JuMP.Containers.VectorizedProductIterator{Tuple{UnitRange{Int64}}}, JuMP.Containers.var"#87#89"{var"#29#30"{Model}}})
#     @ Base ./array.jl:834
#  [10] map(f::Function, A::JuMP.Containers.VectorizedProductIterator{Tuple{UnitRange{Int64}}})
#     @ Base ./abstractarray.jl:3313
#  [11] container(f::Function, indices::JuMP.Containers.VectorizedProductIterator{Tuple{UnitRange{Int64}}}, ::Type{JuMP.Containers.DenseAxisArray}, names::Vector{Any})
#     @ JuMP.Containers ~/.julia/packages/JuMP/7rBNn/src/Containers/container.jl:123
#  [12] container(f::Function, indices::JuMP.Containers.VectorizedProductIterator{Tuple{UnitRange{Int64}}}, ::Type{JuMP.Containers.AutoContainerType}, names::Vector{Any})
#     @ JuMP.Containers ~/.julia/packages/JuMP/7rBNn/src/Containers/container.jl:75
#  [13] macro expansion
#     @ ~/.julia/packages/JuMP/7rBNn/src/macros.jl:393 [inlined]
#  [14] top-level scope
#     @ In[4]:17

# %%
#maybe can construct a better lower bound fir t than 0 - get the largest 15 d_j values and sum them, can't be better than that
#also, can't be worse than sum(d_j) - if all jobs run sequentially on one machine

#reformulating problem c

using JuMP, Cbc, HiGHS
m = Model()

#variables
@variable(m, t >= 0) # makespan
@variable(m, x[M,N], Bin) # x[i,j] = 1 if job j is assigned to machine i
@variable(m, z[M], Bin) # z[i] = 1 if machine i is used

#constraints
@constraint(m, capacity[i in M], sum(a[i,j]*x[i,j] for j in N) <= b[i]) # capacity constraint
@constraint(m, job_assignment[j in N], sum(x[i,j] for i in M) == 1) # each job is assigned to exactly one machine
@expression(m, time_on_machine[i in M], sum(d[j]*x[i,j] for j in N)) # time on machine i
for i in M
    @constraint(m, t >= time_on_machine[i]) # makespan constraint
end
@constraint(m, sum(z[i] for i in M) <= 15) # at most 15 machines are used
# machine i is used if any job is assigned to it, using a diffferent formulation in attempt to improve performance
for i in M
    for j in N
        @constraint(m, x[i,j] <= z[i])
    end
end 

#give a better lower bound for t
@constraint(m, t <= sum(d[j] for j in N)) # t must be less than running all jobs sequentially on one machine
max_d = maximum(d)
d_copy = copy(d)
# Sort the copy in descending order
sorted_d_copy = sort(d_copy, rev=true)
println("sorted_d_copy: ", sorted_d_copy)
# Get the sum of the first 14 elements
sum_d_14 = sum(sorted_d_copy[1:14])
#min_d = minimum(d)
#println("max_d: ", max_d)
#println("min_d: ", min_d)
#since 60 jobs
@constraint(m, t >= max_d) # t must be greater than the longest job
@constraint(m, t <= 52) #where ~51 was the previous best makespan I found
#@constraint(m, t <= sum(d[j] for j in N)-sum_d_14) # t must be less than running all jobs sequentially on one machine

# a machine can't run more than 10 jobs
for i in M
    @constraint(m, sum(x[i,j] for j in N) <= 8)
end
@objective(m, Min, t) # minimize makespan

#solve_and_print(m, x, z, 'C', nothing, t)

#d_sorted = sort(d, rev=false)
#@constraint(m, t >= sum(d_sorted[1:15])) # can't be worse than the sum of the 15 longest jobs (lower bound)
# Out:
# sorted_d_copy: [17.435127730216152, 17.361154160039014, 16.94260481862146, 16.689282684811808, 16.588901856364338, 16.58123058385194, 16.430290126035736, 16.374146329459165, 16.103643196915097, 15.925081771894817, 15.267005597712195, 15.18775886950856, 15.17224979112274, 14.948963968551219, 14.807698184226158, 14.73358672985905, 14.631426963154595, 13.915210637256406, 13.762571097202043, 13.664014964882217, 13.392818867538532, 13.286898361783942, 13.28587854758597, 13.193110894972552, 13.038628506451445, 12.885678601717643, 12.715918323757746, 12.406061591746454, 12.234962478813568, 12.225058463130928, 12.035696930957066, 12.029743944062389, 11.947558879813958, 11.931424047190333, 11.929447435602661, 11.923425937453105, 11.860099749363592, 11.39102183841208, 11.261281779190472, 11.255884718907417, 11.014891392473412, 10.922733225053626, 10.918161141313757, 10.869639665074127, 10.788269446045248, 10.768031851330331, 10.751443725064979, 10.68431045391567, 10.58054690686696, 10.578557532642778, 10.51558699815968, 10.4527976514645, 10.301043392357613, 10.29986166423561, 10.166974828395684, 10.120891944821018, 10.118834610367328, 10.06984154804631, 10.03956361623485, 10.013217968089876]
# t

# %%
#now solve with HiGHS but recoup the original indices
println("Solving Part C using HiGHS")
set_optimizer(m, HiGHS.Optimizer)
#set_optimizer_attribute(m, "time_limit", 16200.0)
#suppress output
set_optimizer_attribute(m, "output_flag", false)
#solve and report time taken
@time(optimize!(m))
for i in M
    if value(z[i]) > 0.99
        println("Machine ", i, " runs jobs ", [j for j in N if value(x[i,j]) > 0.99]) #not correct because of index mapping
        #get the original indices for value i 
        #original_machine = index_map[i]
        #println("val of i: ", i)
        #println("original_machine: ", original_machine)
        #println("Machine ", original_machine, " runs jobs ", [j for j in N if value(x[i,j]) > 0.99])
    end
end
println("Makespan: ", value(t))

# %%
#alternately from previous runs could just set 
@constraint(m, t <= 52) #where ~51 was the previous best makespan I found
